# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/dslim/bert-base-NER"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output = query({
	"inputs": "My name is Sarah Jessica Parker but you can call me Jessica",
})

# %%
output
# Out:
# [{'entity_group': 'PER',
#   'score': 0.9971321225166321,
#   'word': 'Sarah Jessica Parker',
#   'start': 11,
#   'end': 31},
#  {'entity_group': 'PER',
#   'score': 0.9773476123809814,
#   'word': 'Jessica',
#   'start': 52,
#   'end': 59}]

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/microsoft/table-transformer-structure-recognition"
headers = {"Authorization": "Bearer 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"}

def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

output = query("table.png")

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/BAAI/bge-large-zh-v1.5"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output = query({
	"inputs": "Today is a sunny day and I will get some ice cream.",
})
output

# %%
output
# Out:
# {'error': 'Model BAAI/bge-large-zh-v1.5 is currently loading',
#  'estimated_time': 52.08882141113281}

# %%
from langchain.llms import HuggingFaceEndpoint
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"]="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"
# llm=HuggingFaceEndpoint(repo_id='cardiffnlp/twitter-roberta-base-sentiment-latest')

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/Helsinki-NLP/opus-mt-zh-en"
headers = {"Authorization": "Bearer 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"}

def query(payload, target_lang):  # Add target_lang argument
  """
  Performs translation using the specified Hugging Face model and target language.

  Args:
      payload (dict): Dictionary containing the text to be translated in the "inputs" key.
      target_lang (str): The target language code (e.g., "en" for English).

  Returns:
      dict: Response from the Hugging Face API containing the translated text.
  """
  payload["translation"] = target_lang  # Add target language to payload
  response = requests.post(API_URL, headers=headers, json=payload)
  return response.json()

# Example usage
text = "Меня зовут Вольфганг и я живу в Берлине"
target_language = "en"  # Change this to your desired language code

output = query({"inputs": text}, target_language)

print(output)
import requests

API_URL = "https://api-inference.huggingface.co/models/Helsinki-NLP/opus-mt-zh-en"
headers = {"Authorization": "Bearer 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"}

def query(payload, target_lang):  # Add target_lang argument
  """
  Performs translation using the specified Hugging Face model and target language.

  Args:
      payload (dict): Dictionary containing the text to be translated in the "inputs" key.
      target_lang (str): The target language code (e.g., "en" for English).

  Returns:
      dict: Response from the Hugging Face API containing the translated text.
  """
  payload["translation"] = target_lang  # Add target language to payload
  response = requests.post(API_URL, headers=headers, json=payload)
  return response.json()

# Example usage
text = "Меня зовут Вольфганг и я живу в Берлине"
target_language = "en"  # Change this to your desired language code

output = query({"inputs": text}, target_language)

print(output)
# Out:
# [{'translation_text': "Let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go!"}]
# [{'translation_text': "Let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go!"}]

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/google-t5/t5-base"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output = query({
	"inputs": "Hi Hello",
})
output
# Out:
# [{'translation_text': 'Hallo Hallo'}]

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/myshell-ai/MeloTTS-English"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.content

audio_bytes = query({
	"inputs": "The answer to the universe is 42",
})
# You can access the audio with IPython.display for example
from IPython.display import Audio
Audio(audio_bytes)
# Out:
#                 <audio  controls="controls" >
#                     <source src="..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/google-bert/bert-base-uncased"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output = query({
	"inputs": "The answer to the universe is [MASK].",
})
output
# Out:
# [{'score': 0.16963966190814972,
#   'token': 2053,
#   'token_str': 'no',
#   'sequence': 'the answer to the universe is no.'},
#  {'score': 0.0734475702047348,
#   'token': 2498,
#   'token_str': 'nothing',
#   'sequence': 'the answer to the universe is nothing.'},
#  {'score': 0.05803241953253746,
#   'token': 2748,
#   'token_str': 'yes',
#   'sequence': 'the answer to the universe is yes.'},
#  {'score': 0.04395795613527298,
#   'token': 4242,
#   'token_str': 'unknown',
#   'sequence': 'the answer to the universe is unknown.'},
#  {'score': 0.040157515555620193,
#   'token': 3722,
#   'token_str': 'simple',
#   'sequence': 'the answer to the universe is simple.'}]

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/speechbrain/mtl-mimic-voicebank"
headers = {"Authorization": "Bearer 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"}

def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

output = query("data\sample2.flac")
output
# Out:
# [{'label': 'speech_enhanced',
#   'blob': '...',
#   'content-type': 'audio/flac'}]

# %%
import base64
base64_string=output[0]['blob']
audio_bytes = base64.b64decode(base64_string)

# Save the bytes to an audio file
output_file_path = "output_audio.wav"
with open(output_file_path, "wb") as audio_file:
    audio_file.write(audio_bytes)

print(f"Audio saved to {output_file_path}")
# Out:
# Audio saved to output_audio.wav

# %%
type(output[0])
import base64
import pydub  # For audio manipulation

def decode_and_write_audio(response_string, output_filename):
    decoded_bytes = base64.b64decode(response_string)
    with open(output_filename, "wb") as f:
        f.write(decoded_bytes)

    # Optionally, convert the raw bytes to a specific audio format using pydub
    audio = pydub.AudioSegment.from_raw(decoded_bytes)
    audio.export(output_filename + ".wav", format="wav")  # Change format as needed

# Assuming the response is a dictionary with a key holding the encoded audio
audio_string = output[0]['blob']  # Replace with the appropriate key
decode_and_write_audio(audio_string, "output.wav")
# Out:
# c:\Users\mrqad\anaconda3\Lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 16
#      14 # Assuming the response is a dictionary with a key holding the encoded audio
#      15 audio_string = output[0]['blob']  # Replace with the appropriate key
# ---> 16 decode_and_write_audio(audio_string, "output.wav")
#
# Cell In[4], line 11, in decode_and_write_audio(response_string, output_filename)
#       8     f.write(decoded_bytes)
#      10 # Optionally, convert the raw bytes to a specific audio format using pydub
# ---> 11 audio = pydub.AudioSegment.from_raw(decoded_bytes)
#      12 audio.export(output_filename + ".wav", format="wav")
#
# File c:\Users\mrqad\anaconda3\Lib\site-packages\pydub\audio_segment.py:812, in AudioSegment.from_raw(cls, file, **kwargs)
#     810 @classmethod
#     811 def from_raw(cls, file, **kwargs):
# --> 812     return cls.from_file(file, 'raw', sample_width=kwargs['sample_width'], frame_rate=kwargs['frame_rate'],
#     813                          channels=kwargs['channels'])
#
# KeyError: 'sample_width'

# %%
output
# Out:
# {'error': 'Model speechbrain/mtl-mimic-voicebank is currently loading',
#  'estimated_time': 20.0}
